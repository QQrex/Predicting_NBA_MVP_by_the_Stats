# %%
# import dep
import pandas as pd
import time
from datetime import datetime

# %%
# TEST nba.stats.endpoint works
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        28.0
# 9     203076   2021-22        00  1610612747               LAL        29.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# ...

# %%
# call teams to extract team id
from nba_api.stats.static import teams
# get_teams returns a list of 30 dictionaries, each an NBA team.
nba_teams = teams.get_teams()
print('Number of teams fetched: {}'.format(len(nba_teams)))
nba_teams
# Out:
# Number of teams fetched: 30
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
# ...

# %%
# call players
from nba_api.stats.static import players
# get_players returns a list of dictionaries, each representing a player.
nba_players = players.get_players()
print('Number of players fetched: {}'.format(len(nba_players)))
nba_players
# Out:
# Number of players fetched: 4723
# [{'id': 76001,
#   'full_name': 'Alaa Abdelnaby',
#   'first_name': 'Alaa',
#   'last_name': 'Abdelnaby',
#   'is_active': False},
#  {'id': 76002,
#   'full_name': 'Zaid Abdul-Aziz',
#   'first_name': 'Zaid',
#   'last_name': 'Abdul-Aziz',
#   'is_active': False},
#  {'id': 76003,
#   'full_name': 'Kareem Abdul-Jabbar',
#   'first_name': 'Kareem',
#   'last_name': 'Abdul-Jabbar',
#   'is_active': False},
#  {'id': 51,
#   'full_name': 'Mahmoud Abdul-Rauf',
#   'first_name': 'Mahmoud',
#   'last_name': 'Abdul-Rauf',
#   'is_active': False},
#  {'id': 1505,
#   'full_name': 'Tariq Abdul-Wahad',
#   'first_name': 'Tariq',
#   'last_name': 'Abdul-Wahad',
#   'is_active': False},
#  {'id': 949,
#   'full_name': 'Shareef Abdur-Rahim',
#   'first_name': 'Shareef',
#   'last_name': 'Abdur-Rahim',
#   'is_active': False},
#  {'id': 76005,
#   'full_name': 'Tom Abernethy',
#   'first_name': 'Tom',
#   'last_name': 'Abernethy',
#   'is_active': False},
# ...

# %%
# json_normalize teams to df
team_df = pd.json_normalize(nba_teams)

team_df
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
# json_normalize palyers to df
nba_players_df = pd.json_normalize(nba_players)

nba_players_df
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby      False
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz      False
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar      False
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf      False
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad      False
# ...       ...                  ...        ...           ...        ...
# 4718  1627790           Ante Zizic       Ante         Zizic      False
# 4719    78647             Jim Zoet        Jim          Zoet      False
# 4720    78648            Bill Zopf       Bill          Zopf      False
# 4721  1627826          Ivica Zubac      Ivica         Zubac       True
# 4722    78650           Matt Zunic       Matt         Zunic      False
#
# [4723 rows x 5 columns]

# %%
# test league log to extract game_id
from nba_api.stats.endpoints import leaguegamelog
season = leaguegamelog.LeagueGameLog(season='2021-22')

season_2122 = season.get_data_frames()[0]

season_2122
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        22021  1610612747               LAL      Los Angeles Lakers
# 1        22021  1610612744               GSW   Golden State Warriors
# 2        22021  1610612751               BKN           Brooklyn Nets
# 3        22021  1610612749               MIL         Milwaukee Bucks
# 4        22021  1610612754               IND          Indiana Pacers
# ...        ...         ...               ...                     ...
# 2455     22021  1610612738               BOS          Boston Celtics
# 2456     22021  1610612755               PHI      Philadelphia 76ers
# 2457     22021  1610612765               DET         Detroit Pistons
# 2458     22021  1610612750               MIN  Minnesota Timberwolves
# 2459     22021  1610612741               CHI           Chicago Bulls
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  \
# ...

# %%
season_2122.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE'],
#       dtype='object')

# %%
# get list of id's / show length
gameid = season_2122['GAME_ID'].unique()

game_id_list = gameid.tolist()

len(game_id_list)
# Out:
# 1230

# %%
# Test season id list
seasons_test_list = ['2010-11', '2011-12', '2012-13']
all_season_df = pd.DataFrame()

# %%
# Test extract id from season list
for seasons in seasons_test_list:
    season = leaguegamelog.LeagueGameLog(season= seasons)

    season_df = season.get_data_frames()[0]
    
    all_season_df = all_season_df.append(season_df)

# %%
all_season_df
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        22010  1610612747               LAL      Los Angeles Lakers
# 1        22010  1610612745               HOU         Houston Rockets
# 2        22010  1610612738               BOS          Boston Celtics
# 3        22010  1610612748               MIA              Miami Heat
# 4        22010  1610612757               POR  Portland Trail Blazers
# ...        ...         ...               ...                     ...
# 2455     22012  1610612760               OKC   Oklahoma City Thunder
# 2456     22012  1610612763               MEM       Memphis Grizzlies
# 2457     22012  1610612762               UTA               Utah Jazz
# 2458     22012  1610612766               CHA       Charlotte Bobcats
# 2459     22012  1610612739               CLE     Cleveland Cavaliers
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  \
# ...

# %%
all_season_df['SEASON_ID'].value_counts()
# Out:
# 22010    2460
# 22012    2460
# 22011    1980
# Name: SEASON_ID, dtype: int64

# %%
# test extracting boxscore with game id
from nba_api.stats.endpoints import boxscoretraditionalv2
game_test = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id='0022100002')

game_test_df = game_test.get_data_frames()[0]

game_test_df
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022100002  1610612744               GSW  Golden State     203952
# 1   0022100002  1610612744               GSW  Golden State     203110
# 2   0022100002  1610612744               GSW  Golden State    1626172
# 3   0022100002  1610612744               GSW  Golden State    1629673
# 4   0022100002  1610612744               GSW  Golden State     201939
# 5   0022100002  1610612744               GSW  Golden State     202357
# 6   0022100002  1610612744               GSW  Golden State       2738
# 7   0022100002  1610612744               GSW  Golden State    1627814
# 8   0022100002  1610612744               GSW  Golden State    1629308
# 9   0022100002  1610612744               GSW  Golden State     203490
# 10  0022100002  1610612744               GSW  Golden State    1630541
# 11  0022100002  1610612744               GSW  Golden State    1627780
# ...

# %%
# Check dtypes
game_test_df.dtypes
# Out:
# GAME_ID               object
# TEAM_ID                int64
# TEAM_ABBREVIATION     object
# TEAM_CITY             object
# PLAYER_ID              int64
# PLAYER_NAME           object
# NICKNAME              object
# START_POSITION        object
# COMMENT               object
# MIN                   object
# FGM                  float64
# FGA                  float64
# FG_PCT               float64
# FG3M                 float64
# FG3A                 float64
# FG3_PCT              float64
# FTM                  float64
# FTA                  float64
# FT_PCT               float64
# OREB                 float64
# DREB                 float64
# REB                  float64
# AST                  float64
# STL                  float64
# BLK                  float64
# TO                   float64
# PF                   float64
# PTS                  float64
# PLUS_MINUS           float64
# dtype: object

# %%
# change MIN NAN to string 00:00
game_test_df['MIN'] = game_test_df['MIN'].fillna('00:00')

# %%
# convert str to time
pd.to_datetime(game_test_df['MIN'], format = '%M:%S').dt.time
# Out:
# 0     00:25:44
# 1     00:29:56
# 2     00:15:28
# 3     00:25:04
# 4     00:36:11
# 5     00:25:55
# 6     00:22:58
# 7     00:29:04
# 8     00:12:23
# 9     00:11:35
# 10    00:05:34
# 11    00:00:07
# 12    00:36:45
# 13    00:38:55
# 14    00:12:55
# 15    00:30:37
# 16    00:35:08
# 17    00:19:49
# 18    00:26:04
# 19    00:18:44
# 20    00:12:49
# 21    00:08:14
# 22    00:00:00
# 23    00:00:00
# Name: MIN, dtype: object

# %%
# fill all NaN scores to 0
game_test_df.fillna(0)
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022100002  1610612744               GSW  Golden State     203952
# 1   0022100002  1610612744               GSW  Golden State     203110
# 2   0022100002  1610612744               GSW  Golden State    1626172
# 3   0022100002  1610612744               GSW  Golden State    1629673
# 4   0022100002  1610612744               GSW  Golden State     201939
# 5   0022100002  1610612744               GSW  Golden State     202357
# 6   0022100002  1610612744               GSW  Golden State       2738
# 7   0022100002  1610612744               GSW  Golden State    1627814
# 8   0022100002  1610612744               GSW  Golden State    1629308
# 9   0022100002  1610612744               GSW  Golden State     203490
# 10  0022100002  1610612744               GSW  Golden State    1630541
# 11  0022100002  1610612744               GSW  Golden State    1627780
# ...

# %%
# Check columns
game_test_df.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
# filter for columns to keep
game_test.get_data_frames()[0][['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID', 'PLAYER_NAME',
                               'MIN', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
                               'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS']]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022100002  1610612744               GSW  Golden State     203952
# 1   0022100002  1610612744               GSW  Golden State     203110
# 2   0022100002  1610612744               GSW  Golden State    1626172
# 3   0022100002  1610612744               GSW  Golden State    1629673
# 4   0022100002  1610612744               GSW  Golden State     201939
# 5   0022100002  1610612744               GSW  Golden State     202357
# 6   0022100002  1610612744               GSW  Golden State       2738
# 7   0022100002  1610612744               GSW  Golden State    1627814
# 8   0022100002  1610612744               GSW  Golden State    1629308
# 9   0022100002  1610612744               GSW  Golden State     203490
# 10  0022100002  1610612744               GSW  Golden State    1630541
# 11  0022100002  1610612744               GSW  Golden State    1627780
# ...

# %%
# Create test list for call to api
game_list_test = game_id_list[0:20]

game_list_test
# Out:
# ['0022100002',
#  '0022100001',
#  '0022100003',
#  '0022100004',
#  '0022100006',
#  '0022100009',
#  '0022100007',
#  '0022100008',
#  '0022100005',
#  '0022100010',
#  '0022100012',
#  '0022100013',
#  '0022100011',
#  '0022100014',
#  '0022100015',
#  '0022100016',
#  '0022100017',
#  '0022100018',
#  '0022100019',
#  '0022100020']

# %%
# Create empty DataFrame

all_games_df_2122 = pd.DataFrame(columns = ['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 
                                            'PLAYER_ID', 'PLAYER_NAME','MIN', 'MIN', 'FGM','FGA', 
                                            'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 
                                            'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 
                                            'TO', 'PF', 'PTS', 'PLUS_MINUS'])

# create counter
record_counter = 1
set_counter = 1

# %%
# test for loop to call scoreboard data with list of game_id
for i, gameid in enumerate(game_list_test):
    
    if (i % 5 == 0 and i >= 5):
        set_counter += 1
        record_count = 1
        time.sleep(10)
    
    # print status
    print(f'Processing record {record_counter} of Set {set_counter}')
    
    record_counter += 1
    
    game_test = boxscoretraditionalv2.BoxScoreTraditionalV2(game_id= gameid)
    game_test_df = game_test.get_data_frames()[0][['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 
                                                    'PLAYER_ID', 'PLAYER_NAME','MIN', 'MIN', 'FGM','FGA', 
                                                    'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 
                                                    'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 
                                                    'TO', 'PF', 'PTS', 'PLUS_MINUS']]
    all_games_df_2122 = all_games_df_2122.append(game_test_df)
    
print(f'complete')
# Out:
# Processing record 1 of Set 1
# Processing record 2 of Set 1
# Processing record 3 of Set 1
# Processing record 4 of Set 1
# Processing record 5 of Set 1
# Processing record 6 of Set 2
# Processing record 7 of Set 2
# Processing record 8 of Set 2
# Processing record 9 of Set 2
# Processing record 10 of Set 2
# Processing record 11 of Set 3
# Processing record 12 of Set 3
# Processing record 13 of Set 3
# Processing record 14 of Set 3
# Processing record 15 of Set 3
# Processing record 16 of Set 4
# Processing record 17 of Set 4
# Processing record 18 of Set 4
# Processing record 19 of Set 4
# Processing record 20 of Set 4
# complete

# %%
all_games_df_2122
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY PLAYER_ID  \
# 0   0022100002  1610612744               GSW  Golden State    203952
# 1   0022100002  1610612744               GSW  Golden State    203110
# 2   0022100002  1610612744               GSW  Golden State   1626172
# 3   0022100002  1610612744               GSW  Golden State   1629673
# 4   0022100002  1610612744               GSW  Golden State    201939
# ..         ...         ...               ...           ...       ...
# 25  0022100020  1610612738               BOS        Boston    202683
# 26  0022100020  1610612738               BOS        Boston   1630174
# 27  0022100020  1610612738               BOS        Boston   1627823
# 28  0022100020  1610612738               BOS        Boston   1628981
# 29  0022100020  1610612738               BOS        Boston    203953
#
#             PLAYER_NAME    MIN   FGA  FG_PCT  FG3M  ...  OREB  DREB   REB  \
# ...

# %%
all_games_df_2122.columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'MIN', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')
